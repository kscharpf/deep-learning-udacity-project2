# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 5
sample_id = 1123
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 5:
# Samples: 10000
# Label Counts: {0: 1014, 1: 1014, 2: 952, 3: 1016, 4: 997, 5: 1025, 6: 980, 7: 977, 8: 1003, 9: 1022}
# First 20 Labels: [1, 8, 5, 1, 5, 7, 4, 3, 8, 2, 7, 2, 0, 1, 5, 9, 6, 2, 0, 8]
#
# Example of Image 1123:
# Image - Min Value: 3 Max Value: 205
# Image - Shape: (32, 32, 3)
# Label - Label Id: 7 Name: horse

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function

    return (x-np.amin(x))/(np.amax(x) - np.amin(x))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
            
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    xd = np.zeros((len(x),10))
    for i,d in enumerate(x):
        xd[i,d] = 1
    return xd


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# If you're finding it hard to dedicate enough time for this course a week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) to build each layer, except "Convolutional & Max Pooling" layer.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# If you would like to get the most of this course, try to solve all the problems without TF Layers.  Let's begin!
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, \
                          shape = (None, image_shape[0], image_shape[1], image_shape[2]), \
                          name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """, 
    # TODO: Implement Function
    return tf.placeholder(tf.int32, shape=(None, n_classes),name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# Note: You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.  You're free to use any TensorFlow package for all the other layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function

    stride = (1,conv_strides[0], conv_strides[1], 1)
    F_W = tf.Variable(tf.truncated_normal([conv_ksize[0],conv_ksize[1],x_tensor.get_shape().as_list()[3],conv_num_outputs]), name='weights')
    F_b = tf.Variable(tf.zeros(conv_num_outputs), name='biases')
    c = tf.nn.conv2d(x_tensor, F_W, stride, 'SAME') + F_b
    
    p = tf.nn.max_pool(c, ksize=[1, pool_ksize[0], pool_ksize[1], 1], strides=[1, pool_strides[0], pool_strides[1], 1],
                         padding='SAME', name='pool1')
                      
    return p


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
import numpy as np
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    s = x_tensor.get_shape().as_list()
    dim = np.prod(s[1:])
    
    return tf.reshape(x_tensor,(-1, dim))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weights2 = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs]))
    biases2 = tf.Variable(tf.zeros(num_outputs))
    return tf.add(tf.matmul(x_tensor, weights2), biases2)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.
#
# Note: Activation, softmax, or cross entropy shouldn't be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function

    weights2 = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs]))
    biases2 = tf.Variable(tf.zeros(num_outputs))
    return tf.add(tf.matmul(x_tensor, weights2), biases2)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    c1 = conv2d_maxpool(x, 8, [8,8],[2,2],[4,4],[2,2])
    c2 = conv2d_maxpool(c1, 16, [4,4],[1,1],[2,2],[1,1])
    #c3 = conv2d_maxpool(c2, 32, [2,2],[1,1],[1,1],[1,1])

    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    f1 = flatten(c1)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    f2 = fully_conn(f1, 256)
    df2 = tf.nn.dropout(f2, keep_prob)
    f3 = fully_conn(df2, 64)
    df3 = tf.nn.dropout(f3, keep_prob)
    #d3 = tf.nn.dropout(f4, keep_prob)


    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    return output(df3, 10)
    #return output(f4, 10)
    # TODO: return output
    #return None


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    #session.run(tf.initialize_all_variables())
    session.run(optimizer, feed_dict={x:feature_batch, y: label_batch, keep_prob:keep_probability})
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    print(session.run(accuracy, feed_dict={x:feature_batch, y:label_batch, keep_prob:1.0}),  \
          session.run(cost, feed_dict={x:feature_batch, y:label_batch, keep_prob:1.0}))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 200
batch_size = 256
keep_probability = 0.6

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  0.075 5353.13
# Epoch  2, CIFAR-10 Batch 1:  0.225 4097.25
# Epoch  3, CIFAR-10 Batch 1:  0.225 3482.91
# Epoch  4, CIFAR-10 Batch 1:  0.275 2781.24
# Epoch  5, CIFAR-10 Batch 1:  0.225 2466.11
# Epoch  6, CIFAR-10 Batch 1:  0.25 2172.83
# Epoch  7, CIFAR-10 Batch 1:  0.225 1809.76
# Epoch  8, CIFAR-10 Batch 1:  0.3 1574.98
# Epoch  9, CIFAR-10 Batch 1:  0.3 1439.91
# Epoch 10, CIFAR-10 Batch 1:  0.35 1337.39
# Epoch 11, CIFAR-10 Batch 1:  0.35 1219.74
# Epoch 12, CIFAR-10 Batch 1:  0.35 1153.83
# Epoch 13, CIFAR-10 Batch 1:  0.375 1089.98
# Epoch 14, CIFAR-10 Batch 1:  0.425 1014.24
# Epoch 15, CIFAR-10 Batch 1:  0.4 935.362
# Epoch 16, CIFAR-10 Batch 1:  0.4 871.049
# Epoch 17, CIFAR-10 Batch 1:  0.4 794.103
# Epoch 18, CIFAR-10 Batch 1:  0.45 723.65
# Epoch 19, CIFAR-10 Batch 1:  0.45 727.561
# Epoch 20, CIFAR-10 Batch 1:  0.475 651.527
# Epoch 21, CIFAR-10 Batch 1:  0.475 663.57
# Epoch 22, CIFAR-10 Batch 1:  0.475 594.484
# Epoch 23, CIFAR-10 Batch 1:  0.45 555.187
# Epoch 24, CIFAR-10 Batch 1:  0.45 534.501
# Epoch 25, CIFAR-10 Batch 1:  0.45 526.048
# Epoch 26, CIFAR-10 Batch 1:  0.5 492.71
# Epoch 27, CIFAR-10 Batch 1:  0.475 466.36
# Epoch 28, CIFAR-10 Batch 1:  0.5 437.174
# Epoch 29, CIFAR-10 Batch 1:  0.55 423.027
# Epoch 30, CIFAR-10 Batch 1:  0.55 399.587
# Epoch 31, CIFAR-10 Batch 1:  0.55 393.823
# Epoch 32, CIFAR-10 Batch 1:  0.475 385.275
# Epoch 33, CIFAR-10 Batch 1:  0.5 370.687
# Epoch 34, CIFAR-10 Batch 1:  0.525 340.472
# Epoch 35, CIFAR-10 Batch 1:  0.5 323.868
# Epoch 36, CIFAR-10 Batch 1:  0.525 314.248
# Epoch 37, CIFAR-10 Batch 1:  0.55 306.672
# Epoch 38, CIFAR-10 Batch 1:  0.55 279.629
# Epoch 39, CIFAR-10 Batch 1:  0.55 263.701
# Epoch 40, CIFAR-10 Batch 1:  0.575 257.419
# Epoch 41, CIFAR-10 Batch 1:  0.6 255.988
# Epoch 42, CIFAR-10 Batch 1:  0.6 239.364
# Epoch 43, CIFAR-10 Batch 1:  0.525 239.216
# Epoch 44, CIFAR-10 Batch 1:  0.575 222.084
# Epoch 45, CIFAR-10 Batch 1:  0.575 216.555
# Epoch 46, CIFAR-10 Batch 1:  0.6 210.402
# Epoch 47, CIFAR-10 Batch 1:  0.6 201.383
# Epoch 48, CIFAR-10 Batch 1:  0.65 200.206
# Epoch 49, CIFAR-10 Batch 1:  0.625 197.554
# Epoch 50, CIFAR-10 Batch 1:  0.625 198.848
# Epoch 51, CIFAR-10 Batch 1:  0.6 180.616
# Epoch 52, CIFAR-10 Batch 1:  0.575 184.56
# Epoch 53, CIFAR-10 Batch 1:  0.6 181.148
# Epoch 54, CIFAR-10 Batch 1:  0.625 160.137
# Epoch 55, CIFAR-10 Batch 1:  0.625 154.244
# Epoch 56, CIFAR-10 Batch 1:  0.6 146.773
# Epoch 57, CIFAR-10 Batch 1:  0.6 153.969
# Epoch 58, CIFAR-10 Batch 1:  0.6 142.539
# Epoch 59, CIFAR-10 Batch 1:  0.575 144.058
# Epoch 60, CIFAR-10 Batch 1:  0.6 135.979
# Epoch 61, CIFAR-10 Batch 1:  0.625 123.788
# Epoch 62, CIFAR-10 Batch 1:  0.6 129.959
# Epoch 63, CIFAR-10 Batch 1:  0.6 132.36
# Epoch 64, CIFAR-10 Batch 1:  0.6 123.476
# Epoch 65, CIFAR-10 Batch 1:  0.6 113.654
# Epoch 66, CIFAR-10 Batch 1:  0.6 111.633
# Epoch 67, CIFAR-10 Batch 1:  0.6 109.931
# Epoch 68, CIFAR-10 Batch 1:  0.6 109.947
# Epoch 69, CIFAR-10 Batch 1:  0.575 112.529
# Epoch 70, CIFAR-10 Batch 1:  0.575 109.168
# Epoch 71, CIFAR-10 Batch 1:  0.6 96.5103
# Epoch 72, CIFAR-10 Batch 1:  0.625 97.2645
# Epoch 73, CIFAR-10 Batch 1:  0.6 88.0605
# Epoch 74, CIFAR-10 Batch 1:  0.6 82.8399
# Epoch 75, CIFAR-10 Batch 1:  0.65 83.6401
# Epoch 76, CIFAR-10 Batch 1:  0.625 76.8458
# Epoch 77, CIFAR-10 Batch 1:  0.65 79.1255
# Epoch 78, CIFAR-10 Batch 1:  0.65 74.7802
# Epoch 79, CIFAR-10 Batch 1:  0.65 62.8464
# Epoch 80, CIFAR-10 Batch 1:  0.675 66.4699
# Epoch 81, CIFAR-10 Batch 1:  0.65 63.323
# Epoch 82, CIFAR-10 Batch 1:  0.65 61.3901
# Epoch 83, CIFAR-10 Batch 1:  0.675 59.776
# Epoch 84, CIFAR-10 Batch 1:  0.675 58.7053
# Epoch 85, CIFAR-10 Batch 1:  0.7 55.8676
# Epoch 86, CIFAR-10 Batch 1:  0.675 54.7432
# Epoch 87, CIFAR-10 Batch 1:  0.65 54.4747
# Epoch 88, CIFAR-10 Batch 1:  0.7 50.8447
# Epoch 89, CIFAR-10 Batch 1:  0.7 51.8747
# Epoch 90, CIFAR-10 Batch 1:  0.725 47.6695
# Epoch 91, CIFAR-10 Batch 1:  0.725 47.4008
# Epoch 92, CIFAR-10 Batch 1:  0.725 45.7321
# Epoch 93, CIFAR-10 Batch 1:  0.725 43.4656
# Epoch 94, CIFAR-10 Batch 1:  0.75 42.464
# Epoch 95, CIFAR-10 Batch 1:  0.7 42.9529
# Epoch 96, CIFAR-10 Batch 1:  0.7 43.9983
# Epoch 97, CIFAR-10 Batch 1:  0.7 42.6218
# Epoch 98, CIFAR-10 Batch 1:  0.7 45.2289
# Epoch 99, CIFAR-10 Batch 1:  0.7 38.2166
# Epoch 100, CIFAR-10 Batch 1:  0.725 39.8933
# Epoch 101, CIFAR-10 Batch 1:  0.75 34.2063
# Epoch 102, CIFAR-10 Batch 1:  0.775 33.9045
# Epoch 103, CIFAR-10 Batch 1:  0.75 34.309
# Epoch 104, CIFAR-10 Batch 1:  0.75 32.5047
# Epoch 105, CIFAR-10 Batch 1:  0.75 32.761
# Epoch 106, CIFAR-10 Batch 1:  0.75 31.449
# Epoch 107, CIFAR-10 Batch 1:  0.7 30.1455
# Epoch 108, CIFAR-10 Batch 1:  0.75 29.875
# Epoch 109, CIFAR-10 Batch 1:  0.75 29.2477
# Epoch 110, CIFAR-10 Batch 1:  0.75 26.7952
# Epoch 111, CIFAR-10 Batch 1:  0.725 26.6789
# Epoch 112, CIFAR-10 Batch 1:  0.725 26.3555
# Epoch 113, CIFAR-10 Batch 1:  0.725 26.2538
# Epoch 114, CIFAR-10 Batch 1:  0.7 25.0303
# Epoch 115, CIFAR-10 Batch 1:  0.7 23.6799
# Epoch 116, CIFAR-10 Batch 1:  0.7 23.6254
# Epoch 117, CIFAR-10 Batch 1:  0.7 21.9754
# Epoch 118, CIFAR-10 Batch 1:  0.7 21.2179
# Epoch 119, CIFAR-10 Batch 1:  0.65 21.5457
# Epoch 120, CIFAR-10 Batch 1:  0.725 20.5192
# Epoch 121, CIFAR-10 Batch 1:  0.7 20.222
# Epoch 122, CIFAR-10 Batch 1:  0.725 19.1005
# Epoch 123, CIFAR-10 Batch 1:  0.725 19.3896
# Epoch 124, CIFAR-10 Batch 1:  0.675 20.3784
# Epoch 125, CIFAR-10 Batch 1:  0.6 18.8809
# Epoch 126, CIFAR-10 Batch 1:  0.7 17.1596
# Epoch 127, CIFAR-10 Batch 1:  0.675 16.4395
# Epoch 128, CIFAR-10 Batch 1:  0.65 16.5203
# Epoch 129, CIFAR-10 Batch 1:  0.7 15.0944
# Epoch 130, CIFAR-10 Batch 1:  0.55 14.9976
# Epoch 131, CIFAR-10 Batch 1:  0.5 14.7567
# Epoch 132, CIFAR-10 Batch 1:  0.625 14.7354
# Epoch 133, CIFAR-10 Batch 1:  0.6 15.5756
# Epoch 134, CIFAR-10 Batch 1:  0.525 12.4146
# Epoch 135, CIFAR-10 Batch 1:  0.65 12.4034
# Epoch 136, CIFAR-10 Batch 1:  0.6 11.3929
# Epoch 137, CIFAR-10 Batch 1:  0.625 10.6273
# Epoch 138, CIFAR-10 Batch 1:  0.65 10.1553
# Epoch 139, CIFAR-10 Batch 1:  0.65 9.66582
# Epoch 140, CIFAR-10 Batch 1:  0.675 8.76497
# Epoch 141, CIFAR-10 Batch 1:  0.55 8.47703
# Epoch 142, CIFAR-10 Batch 1:  0.625 7.44649
# Epoch 143, CIFAR-10 Batch 1:  0.525 6.569
# Epoch 144, CIFAR-10 Batch 1:  0.55 5.81545
# Epoch 145, CIFAR-10 Batch 1:  0.525 5.28946
# Epoch 146, CIFAR-10 Batch 1:  0.625 4.32492
# Epoch 147, CIFAR-10 Batch 1:  0.65 3.6505
# Epoch 148, CIFAR-10 Batch 1:  0.625 2.97887
# Epoch 149, CIFAR-10 Batch 1:  0.6 2.12805
# Epoch 150, CIFAR-10 Batch 1:  0.55 1.64126
# Epoch 151, CIFAR-10 Batch 1:  0.575 1.48863
# Epoch 152, CIFAR-10 Batch 1:  0.5 1.45925
# Epoch 153, CIFAR-10 Batch 1:  0.65 1.36946
# Epoch 154, CIFAR-10 Batch 1:  0.5 1.46384
# Epoch 155, CIFAR-10 Batch 1:  0.575 1.41537
# Epoch 156, CIFAR-10 Batch 1:  0.675 1.33068
# Epoch 157, CIFAR-10 Batch 1:  0.7 1.33408
# Epoch 158, CIFAR-10 Batch 1:  0.675 1.38047
# Epoch 159, CIFAR-10 Batch 1:  0.575 1.4512
# Epoch 160, CIFAR-10 Batch 1:  0.525 1.48045
# Epoch 161, CIFAR-10 Batch 1:  0.6 1.37056
# Epoch 162, CIFAR-10 Batch 1:  0.575 1.45883
# Epoch 163, CIFAR-10 Batch 1:  0.55 1.50285
# Epoch 164, CIFAR-10 Batch 1:  0.55 1.37821
# Epoch 165, CIFAR-10 Batch 1:  0.6 1.43617
# Epoch 166, CIFAR-10 Batch 1:  0.6 1.33808
# Epoch 167, CIFAR-10 Batch 1:  0.625 1.42913
# Epoch 168, CIFAR-10 Batch 1:  0.575 1.45662
# Epoch 169, CIFAR-10 Batch 1:  0.575 1.42768
# Epoch 170, CIFAR-10 Batch 1:  0.725 1.27115
# Epoch 171, CIFAR-10 Batch 1:  0.65 1.37237
# Epoch 172, CIFAR-10 Batch 1:  0.725 1.3639
# Epoch 173, CIFAR-10 Batch 1:  0.625 1.4013
# Epoch 174, CIFAR-10 Batch 1:  0.65 1.36621
# Epoch 175, CIFAR-10 Batch 1:  0.575 1.38574
# Epoch 176, CIFAR-10 Batch 1:  0.6 1.33111
# Epoch 177, CIFAR-10 Batch 1:  0.625 1.37002
# Epoch 178, CIFAR-10 Batch 1:  0.575 1.34516
# Epoch 179, CIFAR-10 Batch 1:  0.65 1.3192
# Epoch 180, CIFAR-10 Batch 1:  0.625 1.34137
# Epoch 181, CIFAR-10 Batch 1:  0.675 1.30336
# Epoch 182, CIFAR-10 Batch 1:  0.525 1.35697
# Epoch 183, CIFAR-10 Batch 1:  0.65 1.33706
# Epoch 184, CIFAR-10 Batch 1:  0.5 1.39289
# Epoch 185, CIFAR-10 Batch 1:  0.65 1.36551
# Epoch 186, CIFAR-10 Batch 1:  0.575 1.40029
# Epoch 187, CIFAR-10 Batch 1:  0.65 1.29735
# Epoch 188, CIFAR-10 Batch 1:  0.65 1.31948
# Epoch 189, CIFAR-10 Batch 1:  0.625 1.37265
# Epoch 190, CIFAR-10 Batch 1:  0.65 1.28124
# Epoch 191, CIFAR-10 Batch 1:  0.725 1.23834
# Epoch 192, CIFAR-10 Batch 1:  0.55 1.35142
# Epoch 193, CIFAR-10 Batch 1:  0.65 1.30844
# Epoch 194, CIFAR-10 Batch 1:  0.65 1.30285
# Epoch 195, CIFAR-10 Batch 1:  0.7 1.29924
# Epoch 196, CIFAR-10 Batch 1:  0.675 1.33136
# Epoch 197, CIFAR-10 Batch 1:  0.575 1.3232
# Epoch 198, CIFAR-10 Batch 1:  0.575 1.30551
# Epoch 199, CIFAR-10 Batch 1:  0.525 1.36572
# Epoch 200, CIFAR-10 Batch 1:  0.525 1.39938

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  0.1 6383.9
# Epoch  1, CIFAR-10 Batch 2:  0.1 5515.71
# Epoch  1, CIFAR-10 Batch 3:  0.25 3281.99
# Epoch  1, CIFAR-10 Batch 4:  0.275 2489.61
# Epoch  1, CIFAR-10 Batch 5:  0.25 2274.65
# Epoch  2, CIFAR-10 Batch 1:  0.2 2658.32
# Epoch  2, CIFAR-10 Batch 2:  0.2 2319.41
# Epoch  2, CIFAR-10 Batch 3:  0.325 1622.66
# Epoch  2, CIFAR-10 Batch 4:  0.45 1501.9
# Epoch  2, CIFAR-10 Batch 5:  0.325 1209.39
# Epoch  3, CIFAR-10 Batch 1:  0.275 1819.36
# Epoch  3, CIFAR-10 Batch 2:  0.25 1389.44
# Epoch  3, CIFAR-10 Batch 3:  0.45 1084.27
# Epoch  3, CIFAR-10 Batch 4:  0.45 1028.6
# Epoch  3, CIFAR-10 Batch 5:  0.4 853.498
# Epoch  4, CIFAR-10 Batch 1:  0.275 1331.92
# Epoch  4, CIFAR-10 Batch 2:  0.3 1006.57
# Epoch  4, CIFAR-10 Batch 3:  0.5 792.289
# Epoch  4, CIFAR-10 Batch 4:  0.425 837.246
# Epoch  4, CIFAR-10 Batch 5:  0.425 677.751
# Epoch  5, CIFAR-10 Batch 1:  0.3 1065.02
# Epoch  5, CIFAR-10 Batch 2:  0.325 824.779
# Epoch  5, CIFAR-10 Batch 3:  0.5 637.017
# Epoch  5, CIFAR-10 Batch 4:  0.475 685.298
# Epoch  5, CIFAR-10 Batch 5:  0.475 563.607
# Epoch  6, CIFAR-10 Batch 1:  0.35 931.591
# Epoch  6, CIFAR-10 Batch 2:  0.4 670.961
# Epoch  6, CIFAR-10 Batch 3:  0.525 544.942
# Epoch  6, CIFAR-10 Batch 4:  0.525 559.57
# Epoch  6, CIFAR-10 Batch 5:  0.5 486.623
# Epoch  7, CIFAR-10 Batch 1:  0.375 772.538
# Epoch  7, CIFAR-10 Batch 2:  0.4 589.228
# Epoch  7, CIFAR-10 Batch 3:  0.5 476.674
# Epoch  7, CIFAR-10 Batch 4:  0.475 451.904
# Epoch  7, CIFAR-10 Batch 5:  0.5 435.352
# Epoch  8, CIFAR-10 Batch 1:  0.425 647.563
# Epoch  8, CIFAR-10 Batch 2:  0.375 492.519
# Epoch  8, CIFAR-10 Batch 3:  0.5 409.479
# Epoch  8, CIFAR-10 Batch 4:  0.5 405.38
# Epoch  8, CIFAR-10 Batch 5:  0.475 344.288
# Epoch  9, CIFAR-10 Batch 1:  0.425 568.852
# Epoch  9, CIFAR-10 Batch 2:  0.45 413.255
# Epoch  9, CIFAR-10 Batch 3:  0.525 354.261
# Epoch  9, CIFAR-10 Batch 4:  0.475 345.303
# Epoch  9, CIFAR-10 Batch 5:  0.475 311.297
# Epoch 10, CIFAR-10 Batch 1:  0.4 503.821
# Epoch 10, CIFAR-10 Batch 2:  0.425 372.416
# Epoch 10, CIFAR-10 Batch 3:  0.45 306.065
# Epoch 10, CIFAR-10 Batch 4:  0.425 272.932
# Epoch 10, CIFAR-10 Batch 5:  0.575 272.384
# Epoch 11, CIFAR-10 Batch 1:  0.425 419.016
# Epoch 11, CIFAR-10 Batch 2:  0.4 332.74
# Epoch 11, CIFAR-10 Batch 3:  0.525 272.092
# Epoch 11, CIFAR-10 Batch 4:  0.475 236.822
# Epoch 11, CIFAR-10 Batch 5:  0.55 247.519
# Epoch 12, CIFAR-10 Batch 1:  0.5 359.48
# Epoch 12, CIFAR-10 Batch 2:  0.375 295.283
# Epoch 12, CIFAR-10 Batch 3:  0.55 232.865
# Epoch 12, CIFAR-10 Batch 4:  0.425 201.37
# Epoch 12, CIFAR-10 Batch 5:  0.525 197.534
# Epoch 13, CIFAR-10 Batch 1:  0.425 335.972
# Epoch 13, CIFAR-10 Batch 2:  0.45 251.551
# Epoch 13, CIFAR-10 Batch 3:  0.55 209.011
# Epoch 13, CIFAR-10 Batch 4:  0.425 181.111
# Epoch 13, CIFAR-10 Batch 5:  0.55 193.472
# Epoch 14, CIFAR-10 Batch 1:  0.5 273.417
# Epoch 14, CIFAR-10 Batch 2:  0.475 232.336
# Epoch 14, CIFAR-10 Batch 3:  0.575 164.954
# Epoch 14, CIFAR-10 Batch 4:  0.425 147.486
# Epoch 14, CIFAR-10 Batch 5:  0.6 181.584
# Epoch 15, CIFAR-10 Batch 1:  0.525 240.03
# Epoch 15, CIFAR-10 Batch 2:  0.425 208.63
# Epoch 15, CIFAR-10 Batch 3:  0.475 151.908
# Epoch 15, CIFAR-10 Batch 4:  0.475 133.205
# Epoch 15, CIFAR-10 Batch 5:  0.55 168.728
# Epoch 16, CIFAR-10 Batch 1:  0.475 219.481
# Epoch 16, CIFAR-10 Batch 2:  0.45 185.549
# Epoch 16, CIFAR-10 Batch 3:  0.475 134.268
# Epoch 16, CIFAR-10 Batch 4:  0.45 106.538
# Epoch 16, CIFAR-10 Batch 5:  0.6 142.32
# Epoch 17, CIFAR-10 Batch 1:  0.475 192.436
# Epoch 17, CIFAR-10 Batch 2:  0.45 176.436
# Epoch 17, CIFAR-10 Batch 3:  0.5 112.189
# Epoch 17, CIFAR-10 Batch 4:  0.475 95.9699
# Epoch 17, CIFAR-10 Batch 5:  0.55 138.97
# Epoch 18, CIFAR-10 Batch 1:  0.5 160.762
# Epoch 18, CIFAR-10 Batch 2:  0.45 152.661
# Epoch 18, CIFAR-10 Batch 3:  0.425 102.149
# Epoch 18, CIFAR-10 Batch 4:  0.475 83.071
# Epoch 18, CIFAR-10 Batch 5:  0.525 123.464
# Epoch 19, CIFAR-10 Batch 1:  0.55 136.437
# Epoch 19, CIFAR-10 Batch 2:  0.45 132.147
# Epoch 19, CIFAR-10 Batch 3:  0.5 79.8894
# Epoch 19, CIFAR-10 Batch 4:  0.55 71.1932
# Epoch 19, CIFAR-10 Batch 5:  0.575 108.315
# Epoch 20, CIFAR-10 Batch 1:  0.525 130.172
# Epoch 20, CIFAR-10 Batch 2:  0.425 114.276
# Epoch 20, CIFAR-10 Batch 3:  0.45 68.2485
# Epoch 20, CIFAR-10 Batch 4:  0.525 65.4821
# Epoch 20, CIFAR-10 Batch 5:  0.525 100.401
# Epoch 21, CIFAR-10 Batch 1:  0.5 107.753
# Epoch 21, CIFAR-10 Batch 2:  0.45 99.3708
# Epoch 21, CIFAR-10 Batch 3:  0.425 59.8726
# Epoch 21, CIFAR-10 Batch 4:  0.525 55.182
# Epoch 21, CIFAR-10 Batch 5:  0.525 85.7796
# Epoch 22, CIFAR-10 Batch 1:  0.45 91.9564
# Epoch 22, CIFAR-10 Batch 2:  0.45 89.2077
# Epoch 22, CIFAR-10 Batch 3:  0.45 47.2996
# Epoch 22, CIFAR-10 Batch 4:  0.55 46.3812
# Epoch 22, CIFAR-10 Batch 5:  0.5 73.5647
# Epoch 23, CIFAR-10 Batch 1:  0.475 78.4646
# Epoch 23, CIFAR-10 Batch 2:  0.45 76.36
# Epoch 23, CIFAR-10 Batch 3:  0.45 41.2784
# Epoch 23, CIFAR-10 Batch 4:  0.575 38.2836
# Epoch 23, CIFAR-10 Batch 5:  0.5 63.6297
# Epoch 24, CIFAR-10 Batch 1:  0.525 63.976
# Epoch 24, CIFAR-10 Batch 2:  0.45 62.8257
# Epoch 24, CIFAR-10 Batch 3:  0.5 35.0159
# Epoch 24, CIFAR-10 Batch 4:  0.55 31.6931
# Epoch 24, CIFAR-10 Batch 5:  0.5 54.2723
# Epoch 25, CIFAR-10 Batch 1:  0.525 53.6775
# Epoch 25, CIFAR-10 Batch 2:  0.475 53.305
# Epoch 25, CIFAR-10 Batch 3:  0.4 32.6336
# Epoch 25, CIFAR-10 Batch 4:  0.6 27.6342
# Epoch 25, CIFAR-10 Batch 5:  0.5 45.7925
# Epoch 26, CIFAR-10 Batch 1:  0.5 44.8013
# Epoch 26, CIFAR-10 Batch 2:  0.475 47.1362
# Epoch 26, CIFAR-10 Batch 3:  0.525 24.5367
# Epoch 26, CIFAR-10 Batch 4:  0.525 22.3562
# Epoch 26, CIFAR-10 Batch 5:  0.45 35.1885
# Epoch 27, CIFAR-10 Batch 1:  0.425 36.6943
# Epoch 27, CIFAR-10 Batch 2:  0.425 37.8928
# Epoch 27, CIFAR-10 Batch 3:  0.525 18.2525
# Epoch 27, CIFAR-10 Batch 4:  0.5 17.7451
# Epoch 27, CIFAR-10 Batch 5:  0.4 25.6782
# Epoch 28, CIFAR-10 Batch 1:  0.45 29.1998
# Epoch 28, CIFAR-10 Batch 2:  0.375 29.9199
# Epoch 28, CIFAR-10 Batch 3:  0.45 13.1799
# Epoch 28, CIFAR-10 Batch 4:  0.425 13.3887
# Epoch 28, CIFAR-10 Batch 5:  0.5 18.7923
# Epoch 29, CIFAR-10 Batch 1:  0.475 22.9951
# Epoch 29, CIFAR-10 Batch 2:  0.425 22.7592
# Epoch 29, CIFAR-10 Batch 3:  0.425 9.96213
# Epoch 29, CIFAR-10 Batch 4:  0.425 10.0743
# Epoch 29, CIFAR-10 Batch 5:  0.5 13.9892
# Epoch 30, CIFAR-10 Batch 1:  0.5 15.3882
# Epoch 30, CIFAR-10 Batch 2:  0.45 17.9467
# Epoch 30, CIFAR-10 Batch 3:  0.4 7.51226
# Epoch 30, CIFAR-10 Batch 4:  0.475 6.68156
# Epoch 30, CIFAR-10 Batch 5:  0.45 8.88188
# Epoch 31, CIFAR-10 Batch 1:  0.55 10.1265
# Epoch 31, CIFAR-10 Batch 2:  0.375 11.0366
# Epoch 31, CIFAR-10 Batch 3:  0.5 5.33783
# Epoch 31, CIFAR-10 Batch 4:  0.425 4.47786
# Epoch 31, CIFAR-10 Batch 5:  0.45 4.76093
# Epoch 32, CIFAR-10 Batch 1:  0.55 4.86258
# Epoch 32, CIFAR-10 Batch 2:  0.475 6.19295
# Epoch 32, CIFAR-10 Batch 3:  0.4 2.89847
# Epoch 32, CIFAR-10 Batch 4:  0.35 2.75376
# Epoch 32, CIFAR-10 Batch 5:  0.4 2.3844
# Epoch 33, CIFAR-10 Batch 1:  0.475 1.8287
# Epoch 33, CIFAR-10 Batch 2:  0.5 2.06872
# Epoch 33, CIFAR-10 Batch 3:  0.3 1.76599
# Epoch 33, CIFAR-10 Batch 4:  0.5 1.51571
# Epoch 33, CIFAR-10 Batch 5:  0.4 1.6316
# Epoch 34, CIFAR-10 Batch 1:  0.375 1.74301
# Epoch 34, CIFAR-10 Batch 2:  0.525 1.54697
# Epoch 34, CIFAR-10 Batch 3:  0.225 1.74316
# Epoch 34, CIFAR-10 Batch 4:  0.4 1.60157
# Epoch 34, CIFAR-10 Batch 5:  0.425 1.63878
# Epoch 35, CIFAR-10 Batch 1:  0.5 1.64565
# Epoch 35, CIFAR-10 Batch 2:  0.45 1.53582
# Epoch 35, CIFAR-10 Batch 3:  0.4 1.72574
# Epoch 35, CIFAR-10 Batch 4:  0.35 1.67805
# Epoch 35, CIFAR-10 Batch 5:  0.425 1.60216
# Epoch 36, CIFAR-10 Batch 1:  0.4 1.73076
# Epoch 36, CIFAR-10 Batch 2:  0.375 1.62049
# Epoch 36, CIFAR-10 Batch 3:  0.375 1.4952
# Epoch 36, CIFAR-10 Batch 4:  0.475 1.48349
# Epoch 36, CIFAR-10 Batch 5:  0.475 1.60574
# Epoch 37, CIFAR-10 Batch 1:  0.45 1.62982
# Epoch 37, CIFAR-10 Batch 2:  0.425 1.53723
# Epoch 37, CIFAR-10 Batch 3:  0.4 1.53695
# Epoch 37, CIFAR-10 Batch 4:  0.45 1.62209
# Epoch 37, CIFAR-10 Batch 5:  0.475 1.63192
# Epoch 38, CIFAR-10 Batch 1:  0.45 1.57018
# Epoch 38, CIFAR-10 Batch 2:  0.3 1.63691
# Epoch 38, CIFAR-10 Batch 3:  0.425 1.58837
# Epoch 38, CIFAR-10 Batch 4:  0.525 1.48214
# Epoch 38, CIFAR-10 Batch 5:  0.375 1.66583
# Epoch 39, CIFAR-10 Batch 1:  0.45 1.6209
# Epoch 39, CIFAR-10 Batch 2:  0.4 1.6057
# Epoch 39, CIFAR-10 Batch 3:  0.55 1.46919
# Epoch 39, CIFAR-10 Batch 4:  0.35 1.55844
# Epoch 39, CIFAR-10 Batch 5:  0.475 1.60061
# Epoch 40, CIFAR-10 Batch 1:  0.4 1.61351
# Epoch 40, CIFAR-10 Batch 2:  0.45 1.42872
# Epoch 40, CIFAR-10 Batch 3:  0.325 1.62333
# Epoch 40, CIFAR-10 Batch 4:  0.3 1.63266
# Epoch 40, CIFAR-10 Batch 5:  0.525 1.55369
# Epoch 41, CIFAR-10 Batch 1:  0.5 1.51491
# Epoch 41, CIFAR-10 Batch 2:  0.375 1.53547
# Epoch 41, CIFAR-10 Batch 3:  0.475 1.43595
# Epoch 41, CIFAR-10 Batch 4:  0.45 1.49907
# Epoch 41, CIFAR-10 Batch 5:  0.475 1.61623
# Epoch 42, CIFAR-10 Batch 1:  0.45 1.49174
# Epoch 42, CIFAR-10 Batch 2:  0.45 1.47346
# Epoch 42, CIFAR-10 Batch 3:  0.375 1.62149
# Epoch 42, CIFAR-10 Batch 4:  0.475 1.53159
# Epoch 42, CIFAR-10 Batch 5:  0.425 1.595
# Epoch 43, CIFAR-10 Batch 1:  0.45 1.60677
# Epoch 43, CIFAR-10 Batch 2:  0.45 1.44503
# Epoch 43, CIFAR-10 Batch 3:  0.4 1.54016
# Epoch 43, CIFAR-10 Batch 4:  0.475 1.51542
# Epoch 43, CIFAR-10 Batch 5:  0.55 1.51687
# Epoch 44, CIFAR-10 Batch 1:  0.5 1.56222
# Epoch 44, CIFAR-10 Batch 2:  0.4 1.69376
# Epoch 44, CIFAR-10 Batch 3:  0.5 1.46471
# Epoch 44, CIFAR-10 Batch 4:  0.4 1.63965
# Epoch 44, CIFAR-10 Batch 5:  0.525 1.51308
# Epoch 45, CIFAR-10 Batch 1:  0.525 1.45492
# Epoch 45, CIFAR-10 Batch 2:  0.325 1.62948
# Epoch 45, CIFAR-10 Batch 3:  0.6 1.43427
# Epoch 45, CIFAR-10 Batch 4:  0.425 1.58111
# Epoch 45, CIFAR-10 Batch 5:  0.5 1.61407
# Epoch 46, CIFAR-10 Batch 1:  0.525 1.61803
# Epoch 46, CIFAR-10 Batch 2:  0.325 1.61078
# Epoch 46, CIFAR-10 Batch 3:  0.35 1.60195
# Epoch 46, CIFAR-10 Batch 4:  0.375 1.55045
# Epoch 46, CIFAR-10 Batch 5:  0.45 1.59055
# Epoch 47, CIFAR-10 Batch 1:  0.5 1.59772
# Epoch 47, CIFAR-10 Batch 2:  0.4 1.55914
# Epoch 47, CIFAR-10 Batch 3:  0.3 1.62063
# Epoch 47, CIFAR-10 Batch 4:  0.475 1.47301
# Epoch 47, CIFAR-10 Batch 5:  0.4 1.54631
# Epoch 48, CIFAR-10 Batch 1:  0.575 1.41062
# Epoch 48, CIFAR-10 Batch 2:  0.375 1.48329
# Epoch 48, CIFAR-10 Batch 3:  0.425 1.41179
# Epoch 48, CIFAR-10 Batch 4:  0.4 1.58106
# Epoch 48, CIFAR-10 Batch 5:  0.475 1.56567
# Epoch 49, CIFAR-10 Batch 1:  0.45 1.42834
# Epoch 49, CIFAR-10 Batch 2:  0.325 1.58382
# Epoch 49, CIFAR-10 Batch 3:  0.375 1.4867
# Epoch 49, CIFAR-10 Batch 4:  0.475 1.52166
# Epoch 49, CIFAR-10 Batch 5:  0.475 1.5466
# Epoch 50, CIFAR-10 Batch 1:  0.5 1.60005
# Epoch 50, CIFAR-10 Batch 2:  0.425 1.54201
# Epoch 50, CIFAR-10 Batch 3:  0.475 1.60707
# Epoch 50, CIFAR-10 Batch 4:  0.475 1.51314
# Epoch 50, CIFAR-10 Batch 5:  0.475 1.57389
# Epoch 51, CIFAR-10 Batch 1:  0.525 1.64656
# Epoch 51, CIFAR-10 Batch 2:  0.475 1.51342
# Epoch 51, CIFAR-10 Batch 3:  0.45 1.56625
# Epoch 51, CIFAR-10 Batch 4:  0.35 1.70094
# Epoch 51, CIFAR-10 Batch 5:  0.45 1.65285
# Epoch 52, CIFAR-10 Batch 1:  0.55 1.50579
# Epoch 52, CIFAR-10 Batch 2:  0.475 1.50575
# Epoch 52, CIFAR-10 Batch 3:  0.425 1.52722
# Epoch 52, CIFAR-10 Batch 4:  0.375 1.51294
# Epoch 52, CIFAR-10 Batch 5:  0.425 1.63788
# Epoch 53, CIFAR-10 Batch 1:  0.475 1.47983
# Epoch 53, CIFAR-10 Batch 2:  0.425 1.54743
# Epoch 53, CIFAR-10 Batch 3:  0.375 1.49392
# Epoch 53, CIFAR-10 Batch 4:  0.425 1.58011
# Epoch 53, CIFAR-10 Batch 5:  0.475 1.59208
# Epoch 54, CIFAR-10 Batch 1:  0.625 1.48187
# Epoch 54, CIFAR-10 Batch 2:  0.325 1.55379
# Epoch 54, CIFAR-10 Batch 3:  0.45 1.43998
# Epoch 54, CIFAR-10 Batch 4:  0.425 1.54237
# Epoch 54, CIFAR-10 Batch 5:  0.375 1.62141
# Epoch 55, CIFAR-10 Batch 1:  0.5 1.57326
# Epoch 55, CIFAR-10 Batch 2:  0.475 1.41523
# Epoch 55, CIFAR-10 Batch 3:  0.375 1.54903
# Epoch 55, CIFAR-10 Batch 4:  0.55 1.51423
# Epoch 55, CIFAR-10 Batch 5:  0.4 1.57534
# Epoch 56, CIFAR-10 Batch 1:  0.4 1.64826
# Epoch 56, CIFAR-10 Batch 2:  0.3 1.56509
# Epoch 56, CIFAR-10 Batch 3:  0.45 1.40775
# Epoch 56, CIFAR-10 Batch 4:  0.45 1.44523
# Epoch 56, CIFAR-10 Batch 5:  0.475 1.56788
# Epoch 57, CIFAR-10 Batch 1:  0.525 1.45142
# Epoch 57, CIFAR-10 Batch 2:  0.425 1.45408
# Epoch 57, CIFAR-10 Batch 3:  0.45 1.50525
# Epoch 57, CIFAR-10 Batch 4:  0.5 1.52593
# Epoch 57, CIFAR-10 Batch 5:  0.35 1.65037
# Epoch 58, CIFAR-10 Batch 1:  0.45 1.53778
# Epoch 58, CIFAR-10 Batch 2:  0.4 1.5428
# Epoch 58, CIFAR-10 Batch 3:  0.475 1.49212
# Epoch 58, CIFAR-10 Batch 4:  0.4 1.61267
# Epoch 58, CIFAR-10 Batch 5:  0.575 1.44054
# Epoch 59, CIFAR-10 Batch 1:  0.45 1.58545
# Epoch 59, CIFAR-10 Batch 2:  0.4 1.47058
# Epoch 59, CIFAR-10 Batch 3:  0.4 1.51953
# Epoch 59, CIFAR-10 Batch 4:  0.375 1.55635
# Epoch 59, CIFAR-10 Batch 5:  0.525 1.4613
# Epoch 60, CIFAR-10 Batch 1:  0.5 1.57753
# Epoch 60, CIFAR-10 Batch 2:  0.5 1.443
# Epoch 60, CIFAR-10 Batch 3:  0.375 1.52122
# Epoch 60, CIFAR-10 Batch 4:  0.5 1.52637
# Epoch 60, CIFAR-10 Batch 5:  0.525 1.49554
# Epoch 61, CIFAR-10 Batch 1:  0.475 1.66407
# Epoch 61, CIFAR-10 Batch 2:  0.45 1.45728
# Epoch 61, CIFAR-10 Batch 3:  0.4 1.42095
# Epoch 61, CIFAR-10 Batch 4:  0.475 1.47891
# Epoch 61, CIFAR-10 Batch 5:  0.55 1.49622
# Epoch 62, CIFAR-10 Batch 1:  0.5 1.65007
# Epoch 62, CIFAR-10 Batch 2:  0.475 1.53914
# Epoch 62, CIFAR-10 Batch 3:  0.425 1.45591
# Epoch 62, CIFAR-10 Batch 4:  0.5 1.49947
# Epoch 62, CIFAR-10 Batch 5:  0.35 1.6177
# Epoch 63, CIFAR-10 Batch 1:  0.55 1.52945
# Epoch 63, CIFAR-10 Batch 2:  0.425 1.4181
# Epoch 63, CIFAR-10 Batch 3:  0.45 1.40472
# Epoch 63, CIFAR-10 Batch 4:  0.45 1.55043
# Epoch 63, CIFAR-10 Batch 5:  0.525 1.46227
# Epoch 64, CIFAR-10 Batch 1:  0.575 1.44558
# Epoch 64, CIFAR-10 Batch 2:  0.55 1.47746
# Epoch 64, CIFAR-10 Batch 3:  0.475 1.41431
# Epoch 64, CIFAR-10 Batch 4:  0.5 1.50667
# Epoch 64, CIFAR-10 Batch 5:  0.425 1.53018
# Epoch 65, CIFAR-10 Batch 1:  0.55 1.51328
# Epoch 65, CIFAR-10 Batch 2:  0.375 1.47639
# Epoch 65, CIFAR-10 Batch 3:  0.375 1.53278
# Epoch 65, CIFAR-10 Batch 4:  0.425 1.45184
# Epoch 65, CIFAR-10 Batch 5:  0.4 1.52661
# Epoch 66, CIFAR-10 Batch 1:  0.55 1.50391
# Epoch 66, CIFAR-10 Batch 2:  0.425 1.5806
# Epoch 66, CIFAR-10 Batch 3:  0.475 1.49898
# Epoch 66, CIFAR-10 Batch 4:  0.475 1.5144
# Epoch 66, CIFAR-10 Batch 5:  0.45 1.57119
# Epoch 67, CIFAR-10 Batch 1:  0.525 1.49653
# Epoch 67, CIFAR-10 Batch 2:  0.425 1.40521
# Epoch 67, CIFAR-10 Batch 3:  0.425 1.50051
# Epoch 67, CIFAR-10 Batch 4:  0.45 1.51528
# Epoch 67, CIFAR-10 Batch 5:  0.375 1.59119
# Epoch 68, CIFAR-10 Batch 1:  0.575 1.35087
# Epoch 68, CIFAR-10 Batch 2:  0.55 1.38847
# Epoch 68, CIFAR-10 Batch 3:  0.475 1.43618
# Epoch 68, CIFAR-10 Batch 4:  0.525 1.43076
# Epoch 68, CIFAR-10 Batch 5:  0.425 1.5583
# Epoch 69, CIFAR-10 Batch 1:  0.4 1.59408
# Epoch 69, CIFAR-10 Batch 2:  0.425 1.51743
# Epoch 69, CIFAR-10 Batch 3:  0.375 1.52032
# Epoch 69, CIFAR-10 Batch 4:  0.525 1.51673
# Epoch 69, CIFAR-10 Batch 5:  0.5 1.41479
# Epoch 70, CIFAR-10 Batch 1:  0.575 1.45605
# Epoch 70, CIFAR-10 Batch 2:  0.375 1.45011
# Epoch 70, CIFAR-10 Batch 3:  0.45 1.36597
# Epoch 70, CIFAR-10 Batch 4:  0.425 1.48686
# Epoch 70, CIFAR-10 Batch 5:  0.475 1.5181
# Epoch 71, CIFAR-10 Batch 1:  0.575 1.45728
# Epoch 71, CIFAR-10 Batch 2:  0.425 1.41386
# Epoch 71, CIFAR-10 Batch 3:  0.425 1.52301
# Epoch 71, CIFAR-10 Batch 4:  0.45 1.40522
# Epoch 71, CIFAR-10 Batch 5:  0.575 1.37467
# Epoch 72, CIFAR-10 Batch 1:  0.5 1.55427
# Epoch 72, CIFAR-10 Batch 2:  0.45 1.47364
# Epoch 72, CIFAR-10 Batch 3:  0.45 1.52148
# Epoch 72, CIFAR-10 Batch 4:  0.6 1.41201
# Epoch 72, CIFAR-10 Batch 5:  0.5 1.47998
# Epoch 73, CIFAR-10 Batch 1:  0.55 1.49069
# Epoch 73, CIFAR-10 Batch 2:  0.575 1.3544
# Epoch 73, CIFAR-10 Batch 3:  0.475 1.42209
# Epoch 73, CIFAR-10 Batch 4:  0.4 1.51053
# Epoch 73, CIFAR-10 Batch 5:  0.425 1.59643
# Epoch 74, CIFAR-10 Batch 1:  0.425 1.43327
# Epoch 74, CIFAR-10 Batch 2:  0.475 1.47637
# Epoch 74, CIFAR-10 Batch 3:  0.425 1.39623
# Epoch 74, CIFAR-10 Batch 4:  0.425 1.48604
# Epoch 74, CIFAR-10 Batch 5:  0.45 1.42234
# Epoch 75, CIFAR-10 Batch 1:  0.575 1.39342
# Epoch 75, CIFAR-10 Batch 2:  0.525 1.49502
# Epoch 75, CIFAR-10 Batch 3:  0.475 1.40231
# Epoch 75, CIFAR-10 Batch 4:  0.475 1.46386
# Epoch 75, CIFAR-10 Batch 5:  0.375 1.67356
# Epoch 76, CIFAR-10 Batch 1:  0.525 1.47704
# Epoch 76, CIFAR-10 Batch 2:  0.425 1.47311
# Epoch 76, CIFAR-10 Batch 3:  0.4 1.43607
# Epoch 76, CIFAR-10 Batch 4:  0.575 1.40752
# Epoch 76, CIFAR-10 Batch 5:  0.45 1.52907
# Epoch 77, CIFAR-10 Batch 1:  0.55 1.4708
# Epoch 77, CIFAR-10 Batch 2:  0.475 1.40647
# Epoch 77, CIFAR-10 Batch 3:  0.5 1.39607
# Epoch 77, CIFAR-10 Batch 4:  0.375 1.53282
# Epoch 77, CIFAR-10 Batch 5:  0.425 1.49097
# Epoch 78, CIFAR-10 Batch 1:  0.525 1.47003
# Epoch 78, CIFAR-10 Batch 2:  0.525 1.45275
# Epoch 78, CIFAR-10 Batch 3:  0.5 1.46403
# Epoch 78, CIFAR-10 Batch 4:  0.4 1.4772
# Epoch 78, CIFAR-10 Batch 5:  0.55 1.42104
# Epoch 79, CIFAR-10 Batch 1:  0.425 1.52743
# Epoch 79, CIFAR-10 Batch 2:  0.575 1.27144
# Epoch 79, CIFAR-10 Batch 3:  0.525 1.35347
# Epoch 79, CIFAR-10 Batch 4:  0.55 1.41497
# Epoch 79, CIFAR-10 Batch 5:  0.5 1.52211
# Epoch 80, CIFAR-10 Batch 1:  0.425 1.49431
# Epoch 80, CIFAR-10 Batch 2:  0.475 1.30678
# Epoch 80, CIFAR-10 Batch 3:  0.475 1.39156
# Epoch 80, CIFAR-10 Batch 4:  0.375 1.43119
# Epoch 80, CIFAR-10 Batch 5:  0.55 1.40141
# Epoch 81, CIFAR-10 Batch 1:  0.5 1.45299
# Epoch 81, CIFAR-10 Batch 2:  0.375 1.47741
# Epoch 81, CIFAR-10 Batch 3:  0.45 1.3827
# Epoch 81, CIFAR-10 Batch 4:  0.475 1.45223
# Epoch 81, CIFAR-10 Batch 5:  0.55 1.45228
# Epoch 82, CIFAR-10 Batch 1:  0.55 1.3137
# Epoch 82, CIFAR-10 Batch 2:  0.45 1.35775
# Epoch 82, CIFAR-10 Batch 3:  0.525 1.33782
# Epoch 82, CIFAR-10 Batch 4:  0.45 1.43497
# Epoch 82, CIFAR-10 Batch 5:  0.525 1.44573
# Epoch 83, CIFAR-10 Batch 1:  0.575 1.36827
# Epoch 83, CIFAR-10 Batch 2:  0.55 1.4284
# Epoch 83, CIFAR-10 Batch 3:  0.5 1.31867
# Epoch 83, CIFAR-10 Batch 4:  0.55 1.32817
# Epoch 83, CIFAR-10 Batch 5:  0.5 1.44283
# Epoch 84, CIFAR-10 Batch 1:  0.6 1.34529
# Epoch 84, CIFAR-10 Batch 2:  0.5 1.23478
# Epoch 84, CIFAR-10 Batch 3:  0.525 1.39642
# Epoch 84, CIFAR-10 Batch 4:  0.35 1.5407
# Epoch 84, CIFAR-10 Batch 5:  0.525 1.48046
# Epoch 85, CIFAR-10 Batch 1:  0.575 1.39846
# Epoch 85, CIFAR-10 Batch 2:  0.525 1.38143
# Epoch 85, CIFAR-10 Batch 3:  0.525 1.32134
# Epoch 85, CIFAR-10 Batch 4:  0.475 1.41667
# Epoch 85, CIFAR-10 Batch 5:  0.45 1.46185
# Epoch 86, CIFAR-10 Batch 1:  0.6 1.43911
# Epoch 86, CIFAR-10 Batch 2:  0.525 1.36517
# Epoch 86, CIFAR-10 Batch 3:  0.575 1.29338
# Epoch 86, CIFAR-10 Batch 4:  0.45 1.43771
# Epoch 86, CIFAR-10 Batch 5:  0.5 1.51205
# Epoch 87, CIFAR-10 Batch 1:  0.575 1.39286
# Epoch 87, CIFAR-10 Batch 2:  0.525 1.33086
# Epoch 87, CIFAR-10 Batch 3:  0.425 1.3843
# Epoch 87, CIFAR-10 Batch 4:  0.5 1.39905
# Epoch 87, CIFAR-10 Batch 5:  0.475 1.48439
# Epoch 88, CIFAR-10 Batch 1:  0.625 1.35735
# Epoch 88, CIFAR-10 Batch 2:  0.475 1.34802
# Epoch 88, CIFAR-10 Batch 3:  0.5 1.2085
# Epoch 88, CIFAR-10 Batch 4:  0.5 1.37566
# Epoch 88, CIFAR-10 Batch 5:  0.425 1.55206
# Epoch 89, CIFAR-10 Batch 1:  0.525 1.4621
# Epoch 89, CIFAR-10 Batch 2:  0.425 1.38896
# Epoch 89, CIFAR-10 Batch 3:  0.4 1.3104
# Epoch 89, CIFAR-10 Batch 4:  0.475 1.43499
# Epoch 89, CIFAR-10 Batch 5:  0.55 1.342
# Epoch 90, CIFAR-10 Batch 1:  0.55 1.33981
# Epoch 90, CIFAR-10 Batch 2:  0.5 1.24509
# Epoch 90, CIFAR-10 Batch 3:  0.575 1.34469
# Epoch 90, CIFAR-10 Batch 4:  0.525 1.41475
# Epoch 90, CIFAR-10 Batch 5:  0.45 1.45685
# Epoch 91, CIFAR-10 Batch 1:  0.575 1.34913
# Epoch 91, CIFAR-10 Batch 2:  0.55 1.28176
# Epoch 91, CIFAR-10 Batch 3:  0.575 1.21674
# Epoch 91, CIFAR-10 Batch 4:  0.625 1.276
# Epoch 91, CIFAR-10 Batch 5:  0.575 1.43465
# Epoch 92, CIFAR-10 Batch 1:  0.65 1.31867
# Epoch 92, CIFAR-10 Batch 2:  0.5 1.24403
# Epoch 92, CIFAR-10 Batch 3:  0.5 1.23779
# Epoch 92, CIFAR-10 Batch 4:  0.45 1.47506
# Epoch 92, CIFAR-10 Batch 5:  0.525 1.40051
# Epoch 93, CIFAR-10 Batch 1:  0.65 1.29233
# Epoch 93, CIFAR-10 Batch 2:  0.525 1.3266
# Epoch 93, CIFAR-10 Batch 3:  0.55 1.17629
# Epoch 93, CIFAR-10 Batch 4:  0.6 1.28802
# Epoch 93, CIFAR-10 Batch 5:  0.5 1.61271
# Epoch 94, CIFAR-10 Batch 1:  0.6 1.26589
# Epoch 94, CIFAR-10 Batch 2:  0.525 1.27344
# Epoch 94, CIFAR-10 Batch 3:  0.55 1.29551
# Epoch 94, CIFAR-10 Batch 4:  0.55 1.31766
# Epoch 94, CIFAR-10 Batch 5:  0.6 1.40956
# Epoch 95, CIFAR-10 Batch 1:  0.575 1.2818
# Epoch 95, CIFAR-10 Batch 2:  0.475 1.33639
# Epoch 95, CIFAR-10 Batch 3:  0.575 1.24001
# Epoch 95, CIFAR-10 Batch 4:  0.6 1.30005
# Epoch 95, CIFAR-10 Batch 5:  0.525 1.32875
# Epoch 96, CIFAR-10 Batch 1:  0.55 1.36571
# Epoch 96, CIFAR-10 Batch 2:  0.6 1.22871
# Epoch 96, CIFAR-10 Batch 3:  0.55 1.17775
# Epoch 96, CIFAR-10 Batch 4:  0.5 1.32542
# Epoch 96, CIFAR-10 Batch 5:  0.45 1.49727
# Epoch 97, CIFAR-10 Batch 1:  0.6 1.23193
# Epoch 97, CIFAR-10 Batch 2:  0.5 1.33035
# Epoch 97, CIFAR-10 Batch 3:  0.575 1.14139
# Epoch 97, CIFAR-10 Batch 4:  0.625 1.28854
# Epoch 97, CIFAR-10 Batch 5:  0.575 1.32933
# Epoch 98, CIFAR-10 Batch 1:  0.525 1.29434
# Epoch 98, CIFAR-10 Batch 2:  0.525 1.32421
# Epoch 98, CIFAR-10 Batch 3:  0.625 1.16893
# Epoch 98, CIFAR-10 Batch 4:  0.6 1.24333
# Epoch 98, CIFAR-10 Batch 5:  0.525 1.36806
# Epoch 99, CIFAR-10 Batch 1:  0.7 1.3365
# Epoch 99, CIFAR-10 Batch 2:  0.625 1.15801
# Epoch 99, CIFAR-10 Batch 3:  0.525 1.17691
# Epoch 99, CIFAR-10 Batch 4:  0.6 1.35148
# Epoch 99, CIFAR-10 Batch 5:  0.5 1.29056
# Epoch 100, CIFAR-10 Batch 1:  0.6 1.32525
# Epoch 100, CIFAR-10 Batch 2:  0.525 1.25611
# Epoch 100, CIFAR-10 Batch 3:  0.55 1.17587
# Epoch 100, CIFAR-10 Batch 4:  0.575 1.2534
# Epoch 100, CIFAR-10 Batch 5:  0.575 1.3466
# Epoch 101, CIFAR-10 Batch 1:  0.625 1.29535
# Epoch 101, CIFAR-10 Batch 2:  0.575 1.22545
# Epoch 101, CIFAR-10 Batch 3:  0.5 1.19331
# Epoch 101, CIFAR-10 Batch 4:  0.5 1.23503
# Epoch 101, CIFAR-10 Batch 5:  0.575 1.35817
# Epoch 102, CIFAR-10 Batch 1:  0.575 1.37434
# Epoch 102, CIFAR-10 Batch 2:  0.65 1.23239
# Epoch 102, CIFAR-10 Batch 3:  0.525 1.17777
# Epoch 102, CIFAR-10 Batch 4:  0.525 1.24348
# Epoch 102, CIFAR-10 Batch 5:  0.475 1.36534
# Epoch 103, CIFAR-10 Batch 1:  0.6 1.3348
# Epoch 103, CIFAR-10 Batch 2:  0.65 1.13295
# Epoch 103, CIFAR-10 Batch 3:  0.5 1.21183
# Epoch 103, CIFAR-10 Batch 4:  0.55 1.24795
# Epoch 103, CIFAR-10 Batch 5:  0.475 1.32647
# Epoch 104, CIFAR-10 Batch 1:  0.6 1.28878
# Epoch 104, CIFAR-10 Batch 2:  0.65 1.1549
# Epoch 104, CIFAR-10 Batch 3:  0.525 1.17341
# Epoch 104, CIFAR-10 Batch 4:  0.625 1.24116
# Epoch 104, CIFAR-10 Batch 5:  0.45 1.43981
# Epoch 105, CIFAR-10 Batch 1:  0.55 1.35051
# Epoch 105, CIFAR-10 Batch 2:  0.6 1.18313
# Epoch 105, CIFAR-10 Batch 3:  0.575 1.13284
# Epoch 105, CIFAR-10 Batch 4:  0.5 1.29666
# Epoch 105, CIFAR-10 Batch 5:  0.575 1.34467
# Epoch 106, CIFAR-10 Batch 1:  0.575 1.26262
# Epoch 106, CIFAR-10 Batch 2:  0.6 1.15333
# Epoch 106, CIFAR-10 Batch 3:  0.6 1.1768
# Epoch 106, CIFAR-10 Batch 4:  0.65 1.23865
# Epoch 106, CIFAR-10 Batch 5:  0.575 1.31414
# Epoch 107, CIFAR-10 Batch 1:  0.625 1.25179
# Epoch 107, CIFAR-10 Batch 2:  0.575 1.14641
# Epoch 107, CIFAR-10 Batch 3:  0.65 1.09987
# Epoch 107, CIFAR-10 Batch 4:  0.575 1.2258
# Epoch 107, CIFAR-10 Batch 5:  0.5 1.37379
# Epoch 108, CIFAR-10 Batch 1:  0.6 1.2651
# Epoch 108, CIFAR-10 Batch 2:  0.525 1.20916
# Epoch 108, CIFAR-10 Batch 3:  0.6 1.08287
# Epoch 108, CIFAR-10 Batch 4:  0.6 1.21146
# Epoch 108, CIFAR-10 Batch 5:  0.525 1.32185
# Epoch 109, CIFAR-10 Batch 1:  0.55 1.26455
# Epoch 109, CIFAR-10 Batch 2:  0.575 1.18836
# Epoch 109, CIFAR-10 Batch 3:  0.6 1.14068
# Epoch 109, CIFAR-10 Batch 4:  0.575 1.23002
# Epoch 109, CIFAR-10 Batch 5:  0.525 1.24682
# Epoch 110, CIFAR-10 Batch 1:  0.525 1.23974
# Epoch 110, CIFAR-10 Batch 2:  0.625 1.08067
# Epoch 110, CIFAR-10 Batch 3:  0.65 1.113
# Epoch 110, CIFAR-10 Batch 4:  0.625 1.24777
# Epoch 110, CIFAR-10 Batch 5:  0.5 1.30751
# Epoch 111, CIFAR-10 Batch 1:  0.65 1.16762
# Epoch 111, CIFAR-10 Batch 2:  0.55 1.25198
# Epoch 111, CIFAR-10 Batch 3:  0.6 1.09295
# Epoch 111, CIFAR-10 Batch 4:  0.6 1.22945
# Epoch 111, CIFAR-10 Batch 5:  0.5 1.33171
# Epoch 112, CIFAR-10 Batch 1:  0.65 1.17104
# Epoch 112, CIFAR-10 Batch 2:  0.65 1.11993
# Epoch 112, CIFAR-10 Batch 3:  0.65 1.02063
# Epoch 112, CIFAR-10 Batch 4:  0.525 1.24175
# Epoch 112, CIFAR-10 Batch 5:  0.575 1.22926
# Epoch 113, CIFAR-10 Batch 1:  0.6 1.21919
# Epoch 113, CIFAR-10 Batch 2:  0.575 1.07717
# Epoch 113, CIFAR-10 Batch 3:  0.625 1.06944
# Epoch 113, CIFAR-10 Batch 4:  0.65 1.21749
# Epoch 113, CIFAR-10 Batch 5:  0.625 1.2497
# Epoch 114, CIFAR-10 Batch 1:  0.6 1.20298
# Epoch 114, CIFAR-10 Batch 2:  0.6 1.13958
# Epoch 114, CIFAR-10 Batch 3:  0.675 1.02112
# Epoch 114, CIFAR-10 Batch 4:  0.575 1.22419
# Epoch 114, CIFAR-10 Batch 5:  0.55 1.23124
# Epoch 115, CIFAR-10 Batch 1:  0.575 1.29803
# Epoch 115, CIFAR-10 Batch 2:  0.625 1.17076
# Epoch 115, CIFAR-10 Batch 3:  0.6 1.02377
# Epoch 115, CIFAR-10 Batch 4:  0.65 1.24477
# Epoch 115, CIFAR-10 Batch 5:  0.575 1.26389
# Epoch 116, CIFAR-10 Batch 1:  0.65 1.24213
# Epoch 116, CIFAR-10 Batch 2:  0.65 1.14014
# Epoch 116, CIFAR-10 Batch 3:  0.7 0.981667
# Epoch 116, CIFAR-10 Batch 4:  0.55 1.24653
# Epoch 116, CIFAR-10 Batch 5:  0.55 1.21871
# Epoch 117, CIFAR-10 Batch 1:  0.625 1.18262
# Epoch 117, CIFAR-10 Batch 2:  0.65 1.04268
# Epoch 117, CIFAR-10 Batch 3:  0.725 1.02062
# Epoch 117, CIFAR-10 Batch 4:  0.625 1.19893
# Epoch 117, CIFAR-10 Batch 5:  0.625 1.29483
# Epoch 118, CIFAR-10 Batch 1:  0.65 1.20806
# Epoch 118, CIFAR-10 Batch 2:  0.65 1.12572
# Epoch 118, CIFAR-10 Batch 3:  0.625 0.9733
# Epoch 118, CIFAR-10 Batch 4:  0.625 1.1755
# Epoch 118, CIFAR-10 Batch 5:  0.575 1.23298
# Epoch 119, CIFAR-10 Batch 1:  0.575 1.16864
# Epoch 119, CIFAR-10 Batch 2:  0.675 1.08881
# Epoch 119, CIFAR-10 Batch 3:  0.65 0.9869
# Epoch 119, CIFAR-10 Batch 4:  0.55 1.16826
# Epoch 119, CIFAR-10 Batch 5:  0.6 1.19799
# Epoch 120, CIFAR-10 Batch 1:  0.6 1.17381
# Epoch 120, CIFAR-10 Batch 2:  0.7 1.14084
# Epoch 120, CIFAR-10 Batch 3:  0.675 1.00471
# Epoch 120, CIFAR-10 Batch 4:  0.625 1.17032
# Epoch 120, CIFAR-10 Batch 5:  0.575 1.13092
# Epoch 121, CIFAR-10 Batch 1:  0.625 1.14949
# Epoch 121, CIFAR-10 Batch 2:  0.725 1.03907
# Epoch 121, CIFAR-10 Batch 3:  0.675 0.951416
# Epoch 121, CIFAR-10 Batch 4:  0.575 1.10532
# Epoch 121, CIFAR-10 Batch 5:  0.55 1.20521
# Epoch 122, CIFAR-10 Batch 1:  0.65 1.13875
# Epoch 122, CIFAR-10 Batch 2:  0.6 1.13356
# Epoch 122, CIFAR-10 Batch 3:  0.625 1.00394
# Epoch 122, CIFAR-10 Batch 4:  0.625 1.14129
# Epoch 122, CIFAR-10 Batch 5:  0.65 1.20735
# Epoch 123, CIFAR-10 Batch 1:  0.75 1.03417
# Epoch 123, CIFAR-10 Batch 2:  0.65 1.07557
# Epoch 123, CIFAR-10 Batch 3:  0.6 0.941281
# Epoch 123, CIFAR-10 Batch 4:  0.575 1.11104
# Epoch 123, CIFAR-10 Batch 5:  0.6 1.18675
# Epoch 124, CIFAR-10 Batch 1:  0.65 1.14289
# Epoch 124, CIFAR-10 Batch 2:  0.625 1.11276
# Epoch 124, CIFAR-10 Batch 3:  0.725 0.952941
# Epoch 124, CIFAR-10 Batch 4:  0.625 1.10544
# Epoch 124, CIFAR-10 Batch 5:  0.7 1.17434
# Epoch 125, CIFAR-10 Batch 1:  0.6 1.1436
# Epoch 125, CIFAR-10 Batch 2:  0.725 1.002
# Epoch 125, CIFAR-10 Batch 3:  0.675 0.958275
# Epoch 125, CIFAR-10 Batch 4:  0.6 1.11528
# Epoch 125, CIFAR-10 Batch 5:  0.6 1.18488
# Epoch 126, CIFAR-10 Batch 1:  0.625 1.07457
# Epoch 126, CIFAR-10 Batch 2:  0.65 1.03951
# Epoch 126, CIFAR-10 Batch 3:  0.675 0.912166
# Epoch 126, CIFAR-10 Batch 4:  0.55 1.13973
# Epoch 126, CIFAR-10 Batch 5:  0.575 1.18638
# Epoch 127, CIFAR-10 Batch 1:  0.65 1.13956
# Epoch 127, CIFAR-10 Batch 2:  0.675 1.05039
# Epoch 127, CIFAR-10 Batch 3:  0.625 0.943653
# Epoch 127, CIFAR-10 Batch 4:  0.575 1.11075
# Epoch 127, CIFAR-10 Batch 5:  0.65 1.1817
# Epoch 128, CIFAR-10 Batch 1:  0.675 1.11424
# Epoch 128, CIFAR-10 Batch 2:  0.7 1.01911
# Epoch 128, CIFAR-10 Batch 3:  0.675 1.01184
# Epoch 128, CIFAR-10 Batch 4:  0.6 1.11932
# Epoch 128, CIFAR-10 Batch 5:  0.575 1.1938
# Epoch 129, CIFAR-10 Batch 1:  0.55 1.17338
# Epoch 129, CIFAR-10 Batch 2:  0.65 1.07416
# Epoch 129, CIFAR-10 Batch 3:  0.7 0.99813
# Epoch 129, CIFAR-10 Batch 4:  0.575 1.07509
# Epoch 129, CIFAR-10 Batch 5:  0.6 1.11321
# Epoch 130, CIFAR-10 Batch 1:  0.65 1.06897
# Epoch 130, CIFAR-10 Batch 2:  0.6 1.11485
# Epoch 130, CIFAR-10 Batch 3:  0.625 0.92287
# Epoch 130, CIFAR-10 Batch 4:  0.625 1.10978
# Epoch 130, CIFAR-10 Batch 5:  0.625 1.17027
# Epoch 131, CIFAR-10 Batch 1:  0.65 1.1127
# Epoch 131, CIFAR-10 Batch 2:  0.65 1.03633
# Epoch 131, CIFAR-10 Batch 3:  0.75 0.899411
# Epoch 131, CIFAR-10 Batch 4:  0.625 1.06743
# Epoch 131, CIFAR-10 Batch 5:  0.625 1.11929
# Epoch 132, CIFAR-10 Batch 1:  0.65 1.09259
# Epoch 132, CIFAR-10 Batch 2:  0.625 1.09886
# Epoch 132, CIFAR-10 Batch 3:  0.7 0.930045
# Epoch 132, CIFAR-10 Batch 4:  0.575 1.09531
# Epoch 132, CIFAR-10 Batch 5:  0.6 1.16392
# Epoch 133, CIFAR-10 Batch 1:  0.675 1.05803
# Epoch 133, CIFAR-10 Batch 2:  0.625 1.02863
# Epoch 133, CIFAR-10 Batch 3:  0.725 0.927998
# Epoch 133, CIFAR-10 Batch 4:  0.625 1.08488
# Epoch 133, CIFAR-10 Batch 5:  0.675 1.13191
# Epoch 134, CIFAR-10 Batch 1:  0.7 1.03559
# Epoch 134, CIFAR-10 Batch 2:  0.675 1.04453
# Epoch 134, CIFAR-10 Batch 3:  0.675 0.957213
# Epoch 134, CIFAR-10 Batch 4:  0.625 1.09273
# Epoch 134, CIFAR-10 Batch 5:  0.575 1.12269
# Epoch 135, CIFAR-10 Batch 1:  0.675 1.00243
# Epoch 135, CIFAR-10 Batch 2:  0.7 1.05327
# Epoch 135, CIFAR-10 Batch 3:  0.625 0.946295
# Epoch 135, CIFAR-10 Batch 4:  0.625 1.0416
# Epoch 135, CIFAR-10 Batch 5:  0.6 1.16833
# Epoch 136, CIFAR-10 Batch 1:  0.675 1.10413
# Epoch 136, CIFAR-10 Batch 2:  0.65 0.983501
# Epoch 136, CIFAR-10 Batch 3:  0.725 0.891365
# Epoch 136, CIFAR-10 Batch 4:  0.575 1.07709
# Epoch 136, CIFAR-10 Batch 5:  0.675 1.11806
# Epoch 137, CIFAR-10 Batch 1:  0.7 1.03173
# Epoch 137, CIFAR-10 Batch 2:  0.65 0.981337
# Epoch 137, CIFAR-10 Batch 3:  0.7 0.893548
# Epoch 137, CIFAR-10 Batch 4:  0.6 1.11183
# Epoch 137, CIFAR-10 Batch 5:  0.625 1.06471
# Epoch 138, CIFAR-10 Batch 1:  0.7 1.016
# Epoch 138, CIFAR-10 Batch 2:  0.625 0.986503
# Epoch 138, CIFAR-10 Batch 3:  0.625 0.971321
# Epoch 138, CIFAR-10 Batch 4:  0.65 1.10003
# Epoch 138, CIFAR-10 Batch 5:  0.65 1.09524
# Epoch 139, CIFAR-10 Batch 1:  0.625 1.11691
# Epoch 139, CIFAR-10 Batch 2:  0.675 1.03896
# Epoch 139, CIFAR-10 Batch 3:  0.7 0.891935
# Epoch 139, CIFAR-10 Batch 4:  0.625 1.03447
# Epoch 139, CIFAR-10 Batch 5:  0.6 1.13304
# Epoch 140, CIFAR-10 Batch 1:  0.675 1.03652
# Epoch 140, CIFAR-10 Batch 2:  0.65 1.01814
# Epoch 140, CIFAR-10 Batch 3:  0.675 0.916108
# Epoch 140, CIFAR-10 Batch 4:  0.6 1.04202
# Epoch 140, CIFAR-10 Batch 5:  0.65 1.09455
# Epoch 141, CIFAR-10 Batch 1:  0.7 1.03812
# Epoch 141, CIFAR-10 Batch 2:  0.7 1.00618
# Epoch 141, CIFAR-10 Batch 3:  0.725 0.879811
# Epoch 141, CIFAR-10 Batch 4:  0.65 1.06828
# Epoch 141, CIFAR-10 Batch 5:  0.65 1.11246
# Epoch 142, CIFAR-10 Batch 1:  0.675 1.06192
# Epoch 142, CIFAR-10 Batch 2:  0.675 0.947651
# Epoch 142, CIFAR-10 Batch 3:  0.675 0.937972
# Epoch 142, CIFAR-10 Batch 4:  0.625 1.0254
# Epoch 142, CIFAR-10 Batch 5:  0.65 1.09489
# Epoch 143, CIFAR-10 Batch 1:  0.7 1.06125
# Epoch 143, CIFAR-10 Batch 2:  0.675 0.955836
# Epoch 143, CIFAR-10 Batch 3:  0.725 0.853367
# Epoch 143, CIFAR-10 Batch 4:  0.625 1.02612
# Epoch 143, CIFAR-10 Batch 5:  0.725 1.07881
# Epoch 144, CIFAR-10 Batch 1:  0.675 1.1095
# Epoch 144, CIFAR-10 Batch 2:  0.7 0.969023
# Epoch 144, CIFAR-10 Batch 3:  0.675 0.886773
# Epoch 144, CIFAR-10 Batch 4:  0.625 1.02394
# Epoch 144, CIFAR-10 Batch 5:  0.7 1.13
# Epoch 145, CIFAR-10 Batch 1:  0.675 1.06644
# Epoch 145, CIFAR-10 Batch 2:  0.625 0.979157
# Epoch 145, CIFAR-10 Batch 3:  0.7 0.869122
# Epoch 145, CIFAR-10 Batch 4:  0.6 1.0289
# Epoch 145, CIFAR-10 Batch 5:  0.7 1.10461
# Epoch 146, CIFAR-10 Batch 1:  0.65 1.05583
# Epoch 146, CIFAR-10 Batch 2:  0.7 0.955271
# Epoch 146, CIFAR-10 Batch 3:  0.725 0.843638
# Epoch 146, CIFAR-10 Batch 4:  0.65 0.988798
# Epoch 146, CIFAR-10 Batch 5:  0.675 1.0495
# Epoch 147, CIFAR-10 Batch 1:  0.7 1.04007
# Epoch 147, CIFAR-10 Batch 2:  0.675 0.885722
# Epoch 147, CIFAR-10 Batch 3:  0.725 0.847693
# Epoch 147, CIFAR-10 Batch 4:  0.575 1.03622
# Epoch 147, CIFAR-10 Batch 5:  0.575 1.09341
# Epoch 148, CIFAR-10 Batch 1:  0.775 0.974335
# Epoch 148, CIFAR-10 Batch 2:  0.725 0.884058
# Epoch 148, CIFAR-10 Batch 3:  0.7 0.833824
# Epoch 148, CIFAR-10 Batch 4:  0.625 0.973268
# Epoch 148, CIFAR-10 Batch 5:  0.675 1.05346
# Epoch 149, CIFAR-10 Batch 1:  0.725 1.01192
# Epoch 149, CIFAR-10 Batch 2:  0.7 0.884662
# Epoch 149, CIFAR-10 Batch 3:  0.675 0.888876
# Epoch 149, CIFAR-10 Batch 4:  0.725 1.02535
# Epoch 149, CIFAR-10 Batch 5:  0.675 1.0688
# Epoch 150, CIFAR-10 Batch 1:  0.675 1.06364
# Epoch 150, CIFAR-10 Batch 2:  0.725 0.862497
# Epoch 150, CIFAR-10 Batch 3:  0.7 0.819615
# Epoch 150, CIFAR-10 Batch 4:  0.65 1.02291
# Epoch 150, CIFAR-10 Batch 5:  0.65 1.09076
# Epoch 151, CIFAR-10 Batch 1:  0.725 1.05229
# Epoch 151, CIFAR-10 Batch 2:  0.625 0.886667
# Epoch 151, CIFAR-10 Batch 3:  0.675 0.864197
# Epoch 151, CIFAR-10 Batch 4:  0.65 0.984924
# Epoch 151, CIFAR-10 Batch 5:  0.625 1.04996
# Epoch 152, CIFAR-10 Batch 1:  0.7 1.00001
# Epoch 152, CIFAR-10 Batch 2:  0.6 0.939145
# Epoch 152, CIFAR-10 Batch 3:  0.675 0.881703
# Epoch 152, CIFAR-10 Batch 4:  0.625 0.988441
# Epoch 152, CIFAR-10 Batch 5:  0.675 1.01967
# Epoch 153, CIFAR-10 Batch 1:  0.7 1.05886
# Epoch 153, CIFAR-10 Batch 2:  0.7 0.892939
# Epoch 153, CIFAR-10 Batch 3:  0.7 0.87974
# Epoch 153, CIFAR-10 Batch 4:  0.7 0.998239
# Epoch 153, CIFAR-10 Batch 5:  0.65 1.03963
# Epoch 154, CIFAR-10 Batch 1:  0.7 1.07964
# Epoch 154, CIFAR-10 Batch 2:  0.625 0.914418
# Epoch 154, CIFAR-10 Batch 3:  0.675 0.854242
# Epoch 154, CIFAR-10 Batch 4:  0.725 0.96089
# Epoch 154, CIFAR-10 Batch 5:  0.675 1.04853
# Epoch 155, CIFAR-10 Batch 1:  0.775 0.94329
# Epoch 155, CIFAR-10 Batch 2:  0.675 0.854407
# Epoch 155, CIFAR-10 Batch 3:  0.65 0.866158
# Epoch 155, CIFAR-10 Batch 4:  0.625 1.03419
# Epoch 155, CIFAR-10 Batch 5:  0.725 1.03262
# Epoch 156, CIFAR-10 Batch 1:  0.675 1.04283
# Epoch 156, CIFAR-10 Batch 2:  0.65 0.910721
# Epoch 156, CIFAR-10 Batch 3:  0.75 0.823065
# Epoch 156, CIFAR-10 Batch 4:  0.625 1.02705
# Epoch 156, CIFAR-10 Batch 5:  0.675 1.02156
# Epoch 157, CIFAR-10 Batch 1:  0.7 0.995835
# Epoch 157, CIFAR-10 Batch 2:  0.7 0.87521
# Epoch 157, CIFAR-10 Batch 3:  0.7 0.859417
# Epoch 157, CIFAR-10 Batch 4:  0.625 0.993253
# Epoch 157, CIFAR-10 Batch 5:  0.625 1.06851
# Epoch 158, CIFAR-10 Batch 1:  0.675 1.04115
# Epoch 158, CIFAR-10 Batch 2:  0.725 0.889047
# Epoch 158, CIFAR-10 Batch 3:  0.7 0.817888
# Epoch 158, CIFAR-10 Batch 4:  0.65 0.958151
# Epoch 158, CIFAR-10 Batch 5:  0.75 1.04609
# Epoch 159, CIFAR-10 Batch 1:  0.675 1.03108
# Epoch 159, CIFAR-10 Batch 2:  0.7 0.881037
# Epoch 159, CIFAR-10 Batch 3:  0.775 0.828229
# Epoch 159, CIFAR-10 Batch 4:  0.65 0.974539
# Epoch 159, CIFAR-10 Batch 5:  0.725 1.03131
# Epoch 160, CIFAR-10 Batch 1:  0.675 1.01476
# Epoch 160, CIFAR-10 Batch 2:  0.65 0.934738
# Epoch 160, CIFAR-10 Batch 3:  0.775 0.808695
# Epoch 160, CIFAR-10 Batch 4:  0.65 0.949208
# Epoch 160, CIFAR-10 Batch 5:  0.675 1.01791
# Epoch 161, CIFAR-10 Batch 1:  0.7 1.08535
# Epoch 161, CIFAR-10 Batch 2:  0.6 0.925679
# Epoch 161, CIFAR-10 Batch 3:  0.75 0.814249
# Epoch 161, CIFAR-10 Batch 4:  0.65 0.961469
# Epoch 161, CIFAR-10 Batch 5:  0.7 1.03464
# Epoch 162, CIFAR-10 Batch 1:  0.675 1.04233
# Epoch 162, CIFAR-10 Batch 2:  0.625 0.856405
# Epoch 162, CIFAR-10 Batch 3:  0.725 0.80319
# Epoch 162, CIFAR-10 Batch 4:  0.675 0.947051
# Epoch 162, CIFAR-10 Batch 5:  0.775 0.98719
# Epoch 163, CIFAR-10 Batch 1:  0.7 1.02792
# Epoch 163, CIFAR-10 Batch 2:  0.6 0.898174
# Epoch 163, CIFAR-10 Batch 3:  0.775 0.772718
# Epoch 163, CIFAR-10 Batch 4:  0.65 0.96263
# Epoch 163, CIFAR-10 Batch 5:  0.7 0.995526
# Epoch 164, CIFAR-10 Batch 1:  0.7 0.986835
# Epoch 164, CIFAR-10 Batch 2:  0.7 0.8946
# Epoch 164, CIFAR-10 Batch 3:  0.7 0.834287
# Epoch 164, CIFAR-10 Batch 4:  0.675 0.944551
# Epoch 164, CIFAR-10 Batch 5:  0.675 0.992145
# Epoch 165, CIFAR-10 Batch 1:  0.725 1.03959
# Epoch 165, CIFAR-10 Batch 2:  0.8 0.794045
# Epoch 165, CIFAR-10 Batch 3:  0.8 0.783334
# Epoch 165, CIFAR-10 Batch 4:  0.675 0.984403
# Epoch 165, CIFAR-10 Batch 5:  0.7 0.983138
# Epoch 166, CIFAR-10 Batch 1:  0.775 0.993897
# Epoch 166, CIFAR-10 Batch 2:  0.7 0.831302
# Epoch 166, CIFAR-10 Batch 3:  0.75 0.796281
# Epoch 166, CIFAR-10 Batch 4:  0.675 0.951129
# Epoch 166, CIFAR-10 Batch 5:  0.75 0.994049
# Epoch 167, CIFAR-10 Batch 1:  0.75 1.00404
# Epoch 167, CIFAR-10 Batch 2:  0.675 0.837598
# Epoch 167, CIFAR-10 Batch 3:  0.75 0.832142
# Epoch 167, CIFAR-10 Batch 4:  0.7 0.935176
# Epoch 167, CIFAR-10 Batch 5:  0.75 1.02091
# Epoch 168, CIFAR-10 Batch 1:  0.725 1.01332
# Epoch 168, CIFAR-10 Batch 2:  0.65 0.869159
# Epoch 168, CIFAR-10 Batch 3:  0.8 0.772345
# Epoch 168, CIFAR-10 Batch 4:  0.725 0.955299
# Epoch 168, CIFAR-10 Batch 5:  0.7 1.00232
# Epoch 169, CIFAR-10 Batch 1:  0.7 1.05794
# Epoch 169, CIFAR-10 Batch 2:  0.725 0.802835
# Epoch 169, CIFAR-10 Batch 3:  0.75 0.809174
# Epoch 169, CIFAR-10 Batch 4:  0.675 0.951183
# Epoch 169, CIFAR-10 Batch 5:  0.75 1.01411
# Epoch 170, CIFAR-10 Batch 1:  0.7 1.05778
# Epoch 170, CIFAR-10 Batch 2:  0.7 0.816153
# Epoch 170, CIFAR-10 Batch 3:  0.75 0.750119
# Epoch 170, CIFAR-10 Batch 4:  0.675 0.938755
# Epoch 170, CIFAR-10 Batch 5:  0.725 0.9824
# Epoch 171, CIFAR-10 Batch 1:  0.725 1.01674
# Epoch 171, CIFAR-10 Batch 2:  0.725 0.87649
# Epoch 171, CIFAR-10 Batch 3:  0.775 0.77426
# Epoch 171, CIFAR-10 Batch 4:  0.65 0.960735
# Epoch 171, CIFAR-10 Batch 5:  0.725 0.949767
# Epoch 172, CIFAR-10 Batch 1:  0.725 1.05394
# Epoch 172, CIFAR-10 Batch 2:  0.75 0.843831
# Epoch 172, CIFAR-10 Batch 3:  0.725 0.806413
# Epoch 172, CIFAR-10 Batch 4:  0.725 0.925043
# Epoch 172, CIFAR-10 Batch 5:  0.775 0.946423
# Epoch 173, CIFAR-10 Batch 1:  0.675 1.00087
# Epoch 173, CIFAR-10 Batch 2:  0.675 0.824418
# Epoch 173, CIFAR-10 Batch 3:  0.775 0.791346
# Epoch 173, CIFAR-10 Batch 4:  0.675 0.977156
# Epoch 173, CIFAR-10 Batch 5:  0.675 0.988082
# Epoch 174, CIFAR-10 Batch 1:  0.7 1.05284
# Epoch 174, CIFAR-10 Batch 2:  0.725 0.830125
# Epoch 174, CIFAR-10 Batch 3:  0.75 0.788438
# Epoch 174, CIFAR-10 Batch 4:  0.725 0.950425
# Epoch 174, CIFAR-10 Batch 5:  0.7 0.968509
# Epoch 175, CIFAR-10 Batch 1:  0.7 1.05282
# Epoch 175, CIFAR-10 Batch 2:  0.7 0.847565
# Epoch 175, CIFAR-10 Batch 3:  0.775 0.768662
# Epoch 175, CIFAR-10 Batch 4:  0.675 0.955323
# Epoch 175, CIFAR-10 Batch 5:  0.7 0.983227
# Epoch 176, CIFAR-10 Batch 1:  0.7 1.01399
# Epoch 176, CIFAR-10 Batch 2:  0.775 0.789264
# Epoch 176, CIFAR-10 Batch 3:  0.775 0.782591
# Epoch 176, CIFAR-10 Batch 4:  0.725 0.921059
# Epoch 176, CIFAR-10 Batch 5:  0.725 0.980538
# Epoch 177, CIFAR-10 Batch 1:  0.7 1.00837
# Epoch 177, CIFAR-10 Batch 2:  0.675 0.852447
# Epoch 177, CIFAR-10 Batch 3:  0.825 0.784136
# Epoch 177, CIFAR-10 Batch 4:  0.725 0.919239
# Epoch 177, CIFAR-10 Batch 5:  0.7 0.961359
# Epoch 178, CIFAR-10 Batch 1:  0.7 1.03991
# Epoch 178, CIFAR-10 Batch 2:  0.775 0.799623
# Epoch 178, CIFAR-10 Batch 3:  0.725 0.841778
# Epoch 178, CIFAR-10 Batch 4:  0.675 0.918197
# Epoch 178, CIFAR-10 Batch 5:  0.775 0.996381
# Epoch 179, CIFAR-10 Batch 1:  0.7 1.02595
# Epoch 179, CIFAR-10 Batch 2:  0.75 0.829535
# Epoch 179, CIFAR-10 Batch 3:  0.775 0.802246
# Epoch 179, CIFAR-10 Batch 4:  0.7 0.936269
# Epoch 179, CIFAR-10 Batch 5:  0.75 0.963487
# Epoch 180, CIFAR-10 Batch 1:  0.7 1.03514
# Epoch 180, CIFAR-10 Batch 2:  0.75 0.78366
# Epoch 180, CIFAR-10 Batch 3:  0.775 0.792964
# Epoch 180, CIFAR-10 Batch 4:  0.7 0.955446
# Epoch 180, CIFAR-10 Batch 5:  0.65 0.994381
# Epoch 181, CIFAR-10 Batch 1:  0.7 1.04106
# Epoch 181, CIFAR-10 Batch 2:  0.775 0.770468
# Epoch 181, CIFAR-10 Batch 3:  0.775 0.812168
# Epoch 181, CIFAR-10 Batch 4:  0.7 0.920466
# Epoch 181, CIFAR-10 Batch 5:  0.75 0.955387
# Epoch 182, CIFAR-10 Batch 1:  0.7 1.02115
# Epoch 182, CIFAR-10 Batch 2:  0.85 0.743487
# Epoch 182, CIFAR-10 Batch 3:  0.8 0.765023
# Epoch 182, CIFAR-10 Batch 4:  0.7 0.990864
# Epoch 182, CIFAR-10 Batch 5:  0.725 0.971033
# Epoch 183, CIFAR-10 Batch 1:  0.7 1.05622
# Epoch 183, CIFAR-10 Batch 2:  0.7 0.803312
# Epoch 183, CIFAR-10 Batch 3:  0.775 0.809147
# Epoch 183, CIFAR-10 Batch 4:  0.7 0.940078
# Epoch 183, CIFAR-10 Batch 5:  0.8 0.961964
# Epoch 184, CIFAR-10 Batch 1:  0.675 1.03151
# Epoch 184, CIFAR-10 Batch 2:  0.65 0.794053
# Epoch 184, CIFAR-10 Batch 3:  0.8 0.766603
# Epoch 184, CIFAR-10 Batch 4:  0.7 0.923185
# Epoch 184, CIFAR-10 Batch 5:  0.725 0.997498
# Epoch 185, CIFAR-10 Batch 1:  0.7 1.0001
# Epoch 185, CIFAR-10 Batch 2:  0.825 0.803253
# Epoch 185, CIFAR-10 Batch 3:  0.825 0.780439
# Epoch 185, CIFAR-10 Batch 4:  0.7 0.968529
# Epoch 185, CIFAR-10 Batch 5:  0.75 0.940459
# Epoch 186, CIFAR-10 Batch 1:  0.725 1.00267
# Epoch 186, CIFAR-10 Batch 2:  0.8 0.753415
# Epoch 186, CIFAR-10 Batch 3:  0.85 0.768474
# Epoch 186, CIFAR-10 Batch 4:  0.675 0.964614
# Epoch 186, CIFAR-10 Batch 5:  0.8 0.956989
# Epoch 187, CIFAR-10 Batch 1:  0.75 1.01157
# Epoch 187, CIFAR-10 Batch 2:  0.85 0.721803
# Epoch 187, CIFAR-10 Batch 3:  0.775 0.772051
# Epoch 187, CIFAR-10 Batch 4:  0.65 0.952615
# Epoch 187, CIFAR-10 Batch 5:  0.7 0.982344
# Epoch 188, CIFAR-10 Batch 1:  0.675 1.03408
# Epoch 188, CIFAR-10 Batch 2:  0.75 0.765454
# Epoch 188, CIFAR-10 Batch 3:  0.75 0.764334
# Epoch 188, CIFAR-10 Batch 4:  0.675 0.916169
# Epoch 188, CIFAR-10 Batch 5:  0.775 0.9253
# Epoch 189, CIFAR-10 Batch 1:  0.75 0.982113
# Epoch 189, CIFAR-10 Batch 2:  0.775 0.717234
# Epoch 189, CIFAR-10 Batch 3:  0.775 0.752163
# Epoch 189, CIFAR-10 Batch 4:  0.65 0.971635
# Epoch 189, CIFAR-10 Batch 5:  0.75 0.994632
# Epoch 190, CIFAR-10 Batch 1:  0.675 1.02284
# Epoch 190, CIFAR-10 Batch 2:  0.775 0.761456
# Epoch 190, CIFAR-10 Batch 3:  0.775 0.758563
# Epoch 190, CIFAR-10 Batch 4:  0.725 0.911826
# Epoch 190, CIFAR-10 Batch 5:  0.675 0.963313
# Epoch 191, CIFAR-10 Batch 1:  0.725 1.01836
# Epoch 191, CIFAR-10 Batch 2:  0.775 0.762707
# Epoch 191, CIFAR-10 Batch 3:  0.8 0.74439
# Epoch 191, CIFAR-10 Batch 4:  0.7 0.929526
# Epoch 191, CIFAR-10 Batch 5:  0.75 0.955889
# Epoch 192, CIFAR-10 Batch 1:  0.7 1.03244
# Epoch 192, CIFAR-10 Batch 2:  0.8 0.768201
# Epoch 192, CIFAR-10 Batch 3:  0.8 0.760121
# Epoch 192, CIFAR-10 Batch 4:  0.675 0.922482
# Epoch 192, CIFAR-10 Batch 5:  0.725 0.930392
# Epoch 193, CIFAR-10 Batch 1:  0.7 1.02042
# Epoch 193, CIFAR-10 Batch 2:  0.725 0.77747
# Epoch 193, CIFAR-10 Batch 3:  0.8 0.779619
# Epoch 193, CIFAR-10 Batch 4:  0.725 0.893626
# Epoch 193, CIFAR-10 Batch 5:  0.725 0.954505
# Epoch 194, CIFAR-10 Batch 1:  0.725 0.977951
# Epoch 194, CIFAR-10 Batch 2:  0.825 0.719235
# Epoch 194, CIFAR-10 Batch 3:  0.75 0.740678
# Epoch 194, CIFAR-10 Batch 4:  0.75 0.916199
# Epoch 194, CIFAR-10 Batch 5:  0.75 0.934923
# Epoch 195, CIFAR-10 Batch 1:  0.7 1.00965
# Epoch 195, CIFAR-10 Batch 2:  0.775 0.774505
# Epoch 195, CIFAR-10 Batch 3:  0.8 0.750989
# Epoch 195, CIFAR-10 Batch 4:  0.7 0.873607
# Epoch 195, CIFAR-10 Batch 5:  0.75 0.926783
# Epoch 196, CIFAR-10 Batch 1:  0.725 0.985655
# Epoch 196, CIFAR-10 Batch 2:  0.825 0.728739
# Epoch 196, CIFAR-10 Batch 3:  0.825 0.75785
# Epoch 196, CIFAR-10 Batch 4:  0.75 0.90037
# Epoch 196, CIFAR-10 Batch 5:  0.75 0.930758
# Epoch 197, CIFAR-10 Batch 1:  0.7 1.05071
# Epoch 197, CIFAR-10 Batch 2:  0.775 0.719519
# Epoch 197, CIFAR-10 Batch 3:  0.825 0.731307
# Epoch 197, CIFAR-10 Batch 4:  0.7 0.910739
# Epoch 197, CIFAR-10 Batch 5:  0.75 0.922305
# Epoch 198, CIFAR-10 Batch 1:  0.7 1.01294
# Epoch 198, CIFAR-10 Batch 2:  0.85 0.743845
# Epoch 198, CIFAR-10 Batch 3:  0.75 0.724344
# Epoch 198, CIFAR-10 Batch 4:  0.725 0.907839
# Epoch 198, CIFAR-10 Batch 5:  0.8 0.937768
# Epoch 199, CIFAR-10 Batch 1:  0.675 1.03197
# Epoch 199, CIFAR-10 Batch 2:  0.8 0.696164
# Epoch 199, CIFAR-10 Batch 3:  0.775 0.776773
# Epoch 199, CIFAR-10 Batch 4:  0.775 0.907184
# Epoch 199, CIFAR-10 Batch 5:  0.725 0.950379
# Epoch 200, CIFAR-10 Batch 1:  0.725 0.942745
# Epoch 200, CIFAR-10 Batch 2:  0.8 0.719411
# Epoch 200, CIFAR-10 Batch 3:  0.825 0.735695
# Epoch 200, CIFAR-10 Batch 4:  0.675 0.913731
# Epoch 200, CIFAR-10 Batch 5:  0.775 0.952943

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.5568359375

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
